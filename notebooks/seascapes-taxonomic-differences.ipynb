# %% [markdown]
# ## Taxonomic Distribution of Seascapes
# This notebook is in addition to [characterizing_seascapes-taxanomically](https://github.com/ayushanand18/obis-research/blob/main/notebooks/characterizing-seascapes-taxanomically.ipynb) notebook.

# %% [markdown]
# ### importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ### setting data
# We are getting the updated data from this [notebook](https://www.kaggle.com/code/theayushanand/characterizing-seascapes-taxanomically/notebook?scriptVersionId=108579538).

# %%
# Taxonomic Distribution of Seascape Classes
# ==========================================

#     	Seascape Class: 3
# -------------------------------

# class
# Actinopteri         88.258435
# Anthozoa             4.771602
# Demospongiae         3.633082
# Hydrozoa             1.652242
# Hexactinellida       1.101495
# Elasmobranchii       0.356366
# Homoscleromorpha     0.074050
# Aves                 0.050909
# Mammalia             0.032397
# Dinophyceae          0.027769
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 5
# -------------------------------

# class
# Actinopteri       86.466626
# Anthozoa           6.062462
# Demospongiae       4.102878
# Hydrozoa           1.592162
# Hexactinellida     0.489896
# Gastropoda         0.244948
# Bivalvia           0.183711
# Monogenea          0.183711
# Ophiuroidea        0.183711
# Malacostraca       0.122474
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 7
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------
#     	Seascape Class: 10
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------
#     	Seascape Class: 11
# -------------------------------

# class
# Actinopteri       91.803279
# Mammalia           4.918033
# Elasmobranchii     3.278689
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 13
# -------------------------------

# class
# Actinopteri         92.320607
# Demospongiae         3.099291
# Anthozoa             1.732648
# Hydrozoa             1.427084
# Hexactinellida       0.496961
# Malacostraca         0.305564
# Homoscleromorpha     0.258554
# Elasmobranchii       0.154461
# Magnoliopsida        0.036936
# Monogenea            0.030221
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 14
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------
#     	Seascape Class: 15
# -------------------------------

# class
# Actinopteri       98.065143
# Anthozoa           0.997294
# Malacostraca       0.216090
# Demospongiae       0.201450
# Hydrozoa           0.138204
# Elasmobranchii     0.120636
# Ascidiacea         0.048020
# Dinophyceae        0.028109
# Gastropoda         0.028109
# Ophiuroidea        0.022253
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 16
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------
#     	Seascape Class: 17
# -------------------------------

# class
# Actinopteri    100.0
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 18
# -------------------------------

# class
# Actinopteri    100.0
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 20
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------
#     	Seascape Class: 21
# -------------------------------

# class
# Actinopteri        86.315510
# Malacostraca        7.589322
# Anthozoa            2.115526
# Dinophyceae         0.954542
# Polychaeta          0.482381
# Ulvophyceae         0.416973
# Magnoliopsida       0.337258
# Florideophyceae     0.286158
# Mammalia            0.259586
# Ostracoda           0.239146
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 23
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------
#     	Seascape Class: 27
# -------------------------------

# class
# Actinopteri        96.380333
# Malacostraca        1.918135
# Anthozoa            0.380497
# Ulvophyceae         0.183660
# Gastropoda          0.179542
# Polychaeta          0.161423
# Elasmobranchii      0.121891
# Florideophyceae     0.110361
# Mammalia            0.094713
# Magnoliopsida       0.093889
# Name: scientificName, dtype: float64

# -------------------------------
#     	Seascape Class: 28
# -------------------------------

# Series([], Name: scientificName, dtype: float64)

# -------------------------------

# %%
l = [
    "Actinopteri",
    "Anthozoa",
    "Demospongiae",
    "Hydrozoa",
    "Hexactinellida",
    "Elasmobranchii",
    "Homoscleromorpha",
    "Aves",
    "Mammalia",
    "Dinophyceae",
    "Actinopteri",
    "Anthozoa",
    "Demospongiae",
    "Hydrozoa",
    "Hexactinellida",
    "Gastropoda",
    "Bivalvia",
    "Monogenea",
    "Ophiuroidea",
    "Malacostraca",
    "Actinopteri",
    "Mammalia",
    "Elasmobranchii",
    "Actinopteri",
    "Demospongiae",
    "Anthozoa",
    "Hydrozoa",
    "Hexactinellida",
    "Malacostraca",
    "Homoscleromorpha",
    "Elasmobranchii",
    "Magnoliopsida",
    "Monogenea",
    "Demospongiae",
    "Hydrozoa",
    "Elasmobranchii",
    "Ascidiacea",
    "Dinophyceae",
    "Gastropoda",
    "Ophiuroidea",
    "Dinophyceae",
    "Polychaeta",
    "Ulvophyceae",
    "Magnoliopsida",
    "Florideophyceae",
    "Mammalia",
    "Ostracoda",
    "Ulvophyceae",
    "Gastropoda",
    "Elasmobranchii",
    "Florideophyceae",
    "Magnoliopsida",
]

# %%
l = list(set(l))

# %%
df = pd.DataFrame(columns=l)

# %% [markdown]
# ### setting up data

# %%
df.loc[28,:] = np.NaN
df.loc[23,:] = np.NaN
df.loc[20,:] = np.NaN
df.loc[16,:] = np.NaN
df.loc[14,:] = np.NaN
df.loc[7,:] = np.NaN
df.loc[10,:] = np.NaN

# %%
df.loc[3,:] = {"Actinopteri":         88.258435,
"Anthozoa"             :4.771602,
"Demospongiae"         :3.633082,
"Hydrozoa"        :1.652242,
"Hexactinellida"       :1.101495,
"Elasmobranchii"       :0.356366,
"Homoscleromorpha"     :0.074050,
"Aves"                 :0.050909,
"Mammalia"             :0.032397,
"Dinophyceae"          :0.027769}

# %%
df.loc[27,:] = {
"Actinopteri":        96.380333,
"Malacostraca":        1.918135,
"Anthozoa":            0.380497,
"Ulvophyceae":         0.183660,
"Gastropoda":          0.179542,
'Polychaeta':          0.161423,
"Elasmobranchii":      0.121891,
'Florideophyceae':     0.110361,
'Mammalia':            0.094713,
'Magnoliopsida':       0.093889,
}

# %%
df.loc[21,:] = {
"Actinopteri":86.315510,
'Malacostraca'      :  7.589322,
'Anthozoa'         :   2.115526,
'Dinophyceae'     :    0.954542,
'Polychaeta'     :     0.482381,
'Ulvophyceae'   :      0.416973,
'Magnoliopsida':       0.337258,
'Florideophyceae':     0.286158,
'Mammalia':            0.259586,
'Ostracoda':           0.239146,
}

# %%
df.loc[18, :] = {
    "Actinopteri":100,
}

# %%
df.loc[17, :] = {
    "Actinopteri":100,
}

# %%
df.loc[11, :] = {
    "Actinopteri" :      91.803279,
    "Mammalia"     :      4.918033,
    "Elasmobranchii":     3.278689,
}

# %%
df.loc[5, :] = {
'Actinopteri':       86.466626,
'Anthozoa'    :       6.062462,
'Demospongiae' :      4.102878,
'Hydrozoa'      :     1.592162,
'Hexactinellida' :    0.489896,
'Gastropoda':         0.244948,
'Bivalvia'   :        0.183711,
'Monogenea'   :       0.183711,
'Ophiuroidea'  :      0.183711,
"Malacostraca"  :     0.122474,
}

# %%
df.loc[13,:] = {
"Actinopteri":92.320607,
"Demospongiae":3.099291,
"Anthozoa":1.732648,
"Hydrozoa":1.427084,
"Hexactinellida":0.496961,
"Malacostraca":0.305564,
"Homoscleromorpha":0.258554,
"Elasmobranchii":0.154461,
"Magnoliopsida":0.036936,
"Monogenea":0.030221,

}

# %%
df.loc[15, :] = {
"Actinopteri":98.065143,
"Anthozoa":0.997294,
"Malacostraca":0.21609,
"Demospongiae":0.20145,
"Hydrozoa":0.138204,
"Elasmobranchii":0.120636,
"Ascidiacea":0.04802,
"Dinophyceae":0.028109,
"Gastropoda":0.028109,
"Ophiuroidea":0.022253,
}

# %%
df
# Out:
#     Hydrozoa      Aves  Bivalvia Ostracoda Ascidiacea Monogenea Ophiuroidea  \
# 28       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 23       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 20       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 16       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 14       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 7        NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 10       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 3   1.652242  0.050909       NaN       NaN        NaN       NaN         NaN
# 27       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 21       NaN       NaN       NaN  0.239146        NaN       NaN         NaN
# 18       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 17       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 11       NaN       NaN       NaN       NaN        NaN       NaN         NaN
# 5   1.592162       NaN  0.183711       NaN        NaN  0.183711    0.183711
# 13  1.427084       NaN       NaN       NaN        NaN  0.030221         NaN
# 15  0.138204       NaN       NaN       NaN    0.04802       NaN    0.022253
#
#    Dinophyceae Demospongiae Hexactinellida  ... Ulvophyceae Florideophyceae  \
# 28         NaN          NaN            NaN  ...         NaN             NaN
# 23         NaN          NaN            NaN  ...         NaN             NaN
# 20         NaN          NaN            NaN  ...         NaN             NaN
# 16         NaN          NaN            NaN  ...         NaN             NaN
# 14         NaN          NaN            NaN  ...         NaN             NaN
# 7          NaN          NaN            NaN  ...         NaN             NaN
# 10         NaN          NaN            NaN  ...         NaN             NaN
# 3     0.027769     3.633082       1.101495  ...         NaN             NaN
# 27         NaN          NaN            NaN  ...     0.18366        0.110361
# 21    0.954542          NaN            NaN  ...    0.416973        0.286158
# 18         NaN          NaN            NaN  ...         NaN             NaN
# 17         NaN          NaN            NaN  ...         NaN             NaN
# 11         NaN          NaN            NaN  ...         NaN             NaN
# 5          NaN     4.102878       0.489896  ...         NaN             NaN
# 13         NaN     3.099291       0.496961  ...         NaN             NaN
# 15    0.028109      0.20145            NaN  ...         NaN             NaN
#
#    Elasmobranchii Magnoliopsida Homoscleromorpha Gastropoda Polychaeta  \
# 28            NaN           NaN              NaN        NaN        NaN
# 23            NaN           NaN              NaN        NaN        NaN
# 20            NaN           NaN              NaN        NaN        NaN
# 16            NaN           NaN              NaN        NaN        NaN
# 14            NaN           NaN              NaN        NaN        NaN
# 7             NaN           NaN              NaN        NaN        NaN
# 10            NaN           NaN              NaN        NaN        NaN
# 3        0.356366           NaN          0.07405        NaN        NaN
# 27       0.121891      0.093889              NaN   0.179542   0.161423
# 21            NaN      0.337258              NaN        NaN   0.482381
# 18            NaN           NaN              NaN        NaN        NaN
# 17            NaN           NaN              NaN        NaN        NaN
# 11       3.278689           NaN              NaN        NaN        NaN
# 5             NaN           NaN              NaN   0.244948        NaN
# 13       0.154461      0.036936         0.258554        NaN        NaN
# 15       0.120636           NaN              NaN   0.028109        NaN
#
#     Mammalia Malacostraca  Anthozoa
# 28       NaN          NaN       NaN
# 23       NaN          NaN       NaN
# 20       NaN          NaN       NaN
# 16       NaN          NaN       NaN
# 14       NaN          NaN       NaN
# 7        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 3   0.032397          NaN  4.771602
# 27  0.094713     1.918135  0.380497
# 21  0.259586     7.589322  2.115526
# 18       NaN          NaN       NaN
# 17       NaN          NaN       NaN
# 11  4.918033          NaN       NaN
# 5        NaN     0.122474  6.062462
# 13       NaN     0.305564  1.732648
# 15       NaN      0.21609  0.997294
#
# [16 rows x 21 columns]

# %% [markdown]
# ### grouped bar chart - `plotly`

# %%
_df = pd.DataFrame(columns = ['class', 'taxa', 'value'])
_df
# Out:
# Empty DataFrame
# Columns: [class, taxa, value]
# Index: []

# %%
for i in df.iterrows():
    i[1].dropna(inplace=True)
    if(len(i[1])) == 0:
        continue
    temp = pd.DataFrame({
        'class': i[0],
        'taxa': i[1].index,
        'value': i[1].values
    })
    _df = pd.concat([_df, temp])

# %%
_df.index = range(len(_df))

# %%
_df
# Out:
#    class            taxa      value
# 0      3        Hydrozoa   1.652242
# 1      3            Aves   0.050909
# 2      3     Dinophyceae   0.027769
# 3      3    Demospongiae   3.633082
# 4      3  Hexactinellida   1.101495
# ..   ...             ...        ...
# 60    15     Actinopteri  98.065143
# 61    15  Elasmobranchii   0.120636
# 62    15      Gastropoda   0.028109
# 63    15    Malacostraca    0.21609
# 64    15        Anthozoa   0.997294
#
# [65 rows x 3 columns]

# %%
_df.value = _df.value.astype(float)
_df["class"] = _df["class"].astype(str)

# %%
_df.sort_values(by=["class", "value"], ascending=[True, False], inplace=True)

# %%
fig = px.bar(_df, 
             x = "class",
             y = 'value',
             text = _df['taxa'] + " " + _df['value'].round(1).astype(str) + "%",
             color = 'value',
             labels = {
                 'value':'percentage (%)',
                 'class':'seascape class',
             },
             color_continuous_scale = "teal",
            title="Taxanomic distribution v/s Seascape Class")
fig.show()
# Out:
# <div>                            <div id="6bed9899-41f2-403d-8008-c6ef8d37c2f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bed9899-41f2-403d-8008-c6ef8d37c2f9")) {                    Plotly.newPlot(                        "6bed9899-41f2-403d-8008-c6ef8d37c2f9",                        [{"alignmentgroup":"True","hovertemplate":"seascape class=%{x}<br>percentage (%)=%{marker.color}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":[91.803279,4.918033,3.278689,92.320607,3.099291,1.732648,1.427084,0.496961,0.305564,0.258554,0.154461,0.036936,0.030221,98.065143,0.997294,0.21609,0.20145,0.138204,0.120636,0.04802,0.028109,0.028109,0.022253,100